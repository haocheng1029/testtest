# %%
import pandas as pd

df = pd.read_csv("ted_main.csv", encoding = "utf-8")
df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# 5          672  Tony Robbins discusses the "invisible forces" ...      1305
# 6          919  When two young Mormon missionaries knock on Ju...       992
# 7           46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8          852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9          900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10          79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# ...

# %%
df.shape
# Out:
# (2550, 17)

# %%
df[["description","event","url"]]
# Out:
#                                             description           event  \
# 0     Sir Ken Robinson makes an entertaining and pro...         TED2006
# 1     With the same humor and humanity he exuded in ...         TED2006
# 2     New York Times columnist David Pogue takes aim...         TED2006
# 3     In an emotionally charged talk, MacArthur-winn...         TED2006
# 4     You've never seen data presented like this. Wi...         TED2006
# 5     Tony Robbins discusses the "invisible forces" ...         TED2006
# 6     When two young Mormon missionaries knock on Ju...         TED2006
# 7     Architect Joshua Prince-Ramus takes the audien...         TED2006
# 8     Philosopher Dan Dennett calls for religion -- ...         TED2006
# 9     Pastor Rick Warren, author of "The Purpose-Dri...         TED2006
# 10    Accepting his 2006 TED Prize, Cameron Sinclair...         TED2006
# 11    Jehane Noujaim unveils her 2006 TED Prize wish...         TED2006
# ...

# %%
df.iloc[2:7]
# Out:
#    comments                                        description  duration  \
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
# 5       672  Tony Robbins discusses the "invisible forces" ...      1305
# 6       919  When two young Mormon missionaries knock on Ju...       992
#
#      event   film_date  languages   main_speaker  \
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
# 5  TED2006  1138838400         36   Tony Robbins
# 6  TED2006  1140739200         31  Julia Sweeney
#
#                                             name  num_speaker  published_date  \
# 2                  David Pogue: Simplicity sells            1      1151367060
# ...

# %%
df.head(3)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
# 2  TED2006  1140739200         26   David Pogue
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
# 2              David Pogue: Simplicity sells            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# ...

# %%
df.tail(3)
# Out:
#       comments                                        description  duration  \
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event   film_date  languages       main_speaker  \
# 2547       TED2017  1492992000          1     Radhika Nagpal
# 2548  TEDxMileHigh  1499472000          1   Theo E.J. Wilson
# 2549       TED2017  1492992000          1  Karoliina Korppoo
#
#                                                    name  num_speaker  \
# 2547  Radhika Nagpal: What intelligent machines can ...            1
# 2548  Theo E.J. Wilson: A black man goes undercover ...            1
# 2549  Karoliina Korppoo: How a video game might help...            1
#
#       published_date                                            ratings  \
# ...

# %%
df[["url","comments"]].iloc[100:]
# Out:
#                                                     url  comments
# 100   https://www.ted.com/talks/natalie_macmaster_fi...        67
# 101   https://www.ted.com/talks/sergey_brin_and_larr...        56
# 102   https://www.ted.com/talks/stew_says_black_men_...        72
# 103   https://www.ted.com/talks/james_howard_kunstle...       328
# 104   https://www.ted.com/talks/david_kelley_on_huma...        32
# 105   https://www.ted.com/talks/stewart_brand_on_squ...        99
# 106   https://www.ted.com/talks/jeff_hawkins_on_how_...       230
# 107   https://www.ted.com/talks/tierney_thys_swims_w...        87
# 108   https://www.ted.com/talks/blaise_aguera_y_arca...       260
# 109   https://www.ted.com/talks/john_doerr_sees_salv...       295
# 110   https://www.ted.com/talks/ngozi_okonjo_iweala_...       127
# 111   https://www.ted.com/talks/anand_agarawala_demo...       124
# 112   https://www.ted.com/talks/bob_thurman_says_we_...       220
# ...

# %%
test = df.iloc[:3]
test
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
# 2  TED2006  1140739200         26   David Pogue
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
# 2              David Pogue: Simplicity sells            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# ...

# %%
test.shape
# Out:
# (3, 17)

# %%
test[[True, False, True]]
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 2       124  New York Times columnist David Pogue takes aim...      1286
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 2  TED2006  1140739200         26   David Pogue
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 2              David Pogue: Simplicity sells            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
#
#                                        related_talks    speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...       Author/educator
# ...

# %%
boolen_filter = df["description"].str.contains(r"\bSir\b")
boolen_filter
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2520    False
# 2521    False
# 2522    False
# 2523    False
# 2524    False
# 2525    False
# 2526    False
# 2527    False
# 2528    False
# 2529    False
# 2530    False
# 2531    False
# 2532    False
# 2533    False
# 2534    False
# 2535    False
# 2536    False
# 2537    False
# 2538    False
# 2539    False
# 2540    False
# 2541    False
# 2542    False
# 2543    False
# 2544    False
# 2545    False
# 2546    False
# 2547    False
# 2548    False
# 2549    False
# ...

# %%
df[boolen_filter]
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 54         203  Speaking as both an astronomer and "a concerne...      1046
# 692       1234  In this poignant, funny follow-up to his fable...      1008
# 833        473  In this talk from RSA Animate, Sir Ken Robinso...       700
# 1502       634  Sir Ken Robinson outlines 3 principles crucial...      1151
# 1802        59  Sir Tim Berners-Lee invented the World Wide We...       403
#
#                     event   film_date  languages     main_speaker  \
# 0                 TED2006  1140825600         60     Ken Robinson
# 54         TEDGlobal 2005  1121299200         29      Martin Rees
# 692               TED2010  1265414400         57     Ken Robinson
# 833           RSA Animate  1287014400          0     Ken Robinson
# 1502  TED Talks Education  1366675200         43     Ken Robinson
# ...

# %%
filter = df[ df["description"].str.contains(r"\bSir\b")]
filter.to_csv("test.csv", encoding="utf-8", index = False)

# %%
readcsv = pd.read_csv("test.csv", encoding="utf-8")
readcsv
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       203  Speaking as both an astronomer and "a concerne...      1046
# 2      1234  In this poignant, funny follow-up to his fable...      1008
# 3       473  In this talk from RSA Animate, Sir Ken Robinso...       700
# 4       634  Sir Ken Robinson outlines 3 principles crucial...      1151
# 5        59  Sir Tim Berners-Lee invented the World Wide We...       403
#
#                  event   film_date  languages     main_speaker  \
# 0              TED2006  1140825600         60     Ken Robinson
# 1       TEDGlobal 2005  1121299200         29      Martin Rees
# 2              TED2010  1265414400         57     Ken Robinson
# 3          RSA Animate  1287014400          0     Ken Robinson
# 4  TED Talks Education  1366675200         43     Ken Robinson
# 5              TED2014  1394582400         29  Tim Berners-Lee
#
# ...

# %%
readcsv.shape
# Out:
# (6, 17)

# %%
def tag_filter(element):
    tag_list = eval(element)
    
    if 'children' in tag_list:
        return True
    else:
        return False

bollen_filter = df["tags"].apply(tag_filter)
boolen_filter
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2520    False
# 2521    False
# 2522    False
# 2523    False
# 2524    False
# 2525    False
# 2526    False
# 2527    False
# 2528    False
# 2529    False
# 2530    False
# 2531    False
# 2532    False
# 2533    False
# 2534    False
# 2535    False
# 2536    False
# 2537    False
# 2538    False
# 2539    False
# 2540    False
# 2541    False
# 2542    False
# 2543    False
# 2544    False
# 2545    False
# 2546    False
# 2547    False
# 2548    False
# 2549    False
# ...

# %%
df[boolen_filter][ ['description','tags']]
# Out:
#                                             description  \
# 0     Sir Ken Robinson makes an entertaining and pro...
# 54    Speaking as both an astronomer and "a concerne...
# 692   In this poignant, funny follow-up to his fable...
# 833   In this talk from RSA Animate, Sir Ken Robinso...
# 1502  Sir Ken Robinson outlines 3 principles crucial...
# 1802  Sir Tim Berners-Lee invented the World Wide We...
#
#                                                    tags
# 0     ['children', 'creativity', 'culture', 'dance',...
# 54    ['astronomy', 'climate change', 'complexity', ...
# 692   ['TED Brain Trust', 'children', 'creativity', ...
# 833   ['TED Brain Trust', 'business', 'children', 'd...
# 1502  ['culture', 'education', 'student', 'teaching'...
# 1802  ['Internet', 'global issues', 'open-source', '...

# %%
def tag_filter(element, filter_tag):
    tag_list = eval(element)
    
    if filter_tag in tag_list:
        return True
    else:
        return False

boolen_filter = df["tags"].apply(tag_filter, filter_tag = 'Asia')
boolen_filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2520    False
# 2521    False
# 2522    False
# 2523    False
# 2524    False
# 2525    False
# 2526    False
# 2527    False
# 2528    False
# 2529    False
# 2530    False
# 2531    False
# 2532    False
# 2533    False
# 2534    False
# 2535    False
# 2536    False
# 2537    False
# 2538    False
# 2539    False
# 2540    False
# 2541    False
# 2542    False
# 2543    False
# 2544    False
# 2545    False
# 2546    False
# 2547    False
# 2548    False
# 2549    False
# ...

# %%
test2 = df[boolen_filter][['description','tags']]
test2
# Out:
#                                             description  \
# 4     You've never seen data presented like this. Wi...
# 117   Researcher Hans Rosling uses his cool data too...
# 359   Reporter Jennifer 8. Lee talks about her hunt ...
# 448   Nandan Nilekani, the visionary co-founder of o...
# 484   TED Fellow Sophal Ear shares the compelling st...
# 502   Talking at the US State Department this summer...
# 512   Vishal Vaid and his band explore a traditional...
# 523   Many people think the lines on the map no long...
# 558   Hans Rosling was a young guest student in Indi...
# 567   Sunitha Krishnan has dedicated her life to res...
# 573   Ryan Lobo has traveled the world, taking photo...
# 577   Shaffi Mather explains why he left his first c...
# 597   Collector Ravin Agrawal delivers a glowing int...
# 854   Speaking at a TED Salon in London, Martin Jacq...
# 1011  Economist Yasheng Huang compares China to Indi...
# 1027  Yang Lan, a journalist and entrepreneur who's ...
# ...

# %%
test2.shape
# Out:
# (26, 2)
